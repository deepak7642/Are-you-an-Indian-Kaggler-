# %% [markdown]
# # Heyy.... there, Are you an Indian Kaggler !!??
#
#
#
#
#
#
# ## By   Deepak Kaura

# %% [markdown]
# Namaste to all 🙏🏻!!!, whosoever reading this whether from India or Other Country you are Welcome to My small World.
#
# Below I have done few amazing visualization on the behaviour of Indian Students on Kaggle.
#
# Being an Indian student myself, I was curious to know how other Indian Students were using Kaggle and proceeding in their Data Science Journey.

# %%
from IPython.display import Image
Image(filename='India.jpg')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px
from plotly.offline import iplot

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv("kaggle_survey_2021_responses.csv")
# Out:
# C:\Users\DEEPAK KAURA\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning:
#
# Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df = df.iloc[1:, :]
df.head()
# Out:
#   Time from Start to Finish (seconds)     Q1   Q2         Q3  \
# 1                                 910  50-54  Man      India
# 2                                 784  50-54  Man  Indonesia
# 3                                 924  22-24  Man   Pakistan
# 4                                 575  45-49  Man     Mexico
# 5                                 781  45-49  Man      India
#
#                   Q4                       Q5          Q6 Q7_Part_1 Q7_Part_2  \
# 1  Bachelor’s degree                    Other  5-10 years    Python         R
# 2    Master’s degree  Program/Project Manager   20+ years       NaN       NaN
# 3    Master’s degree        Software Engineer   1-3 years    Python       NaN
# 4    Doctoral degree       Research Scientist   20+ years    Python       NaN
# 5    Doctoral degree                    Other   < 1 years    Python       NaN
#
#   Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6 Q7_Part_7 Q7_Part_8 Q7_Part_9  \
# ...

# %%
df = df[(df['Q3'] == 'India') & (df['Q5'] == 'Student')]
df.head()
# Out:
#    Time from Start to Finish (seconds)     Q1     Q2     Q3  \
# 7                                  141  18-21  Woman  India
# 12                                3081  18-21  Woman  India
# 13                                1922  18-21  Woman  India
# 25                                 630  18-21    Man  India
# 30                                 501  18-21    Man  India
#
#                                                    Q4       Q5         Q6  \
# 7   Some college/university study without earning ...  Student  1-3 years
# 12                                    Master’s degree  Student  < 1 years
# 13                                    Master’s degree  Student  < 1 years
# 25                                  Bachelor’s degree  Student  1-3 years
# 30                                  Bachelor’s degree  Student  < 1 years
#
#    Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 7        NaN       NaN       NaN       NaN       C++      Java  Javascript
# ...

# %%
print(f"We have Data for {len(df)} Indian Students")
# Out:
# We have Data for 2845 Indian Students

# %% [markdown]
# # Education

# %%
temp_df = df["Q4"].value_counts().reset_index()

trace1 = go.Bar(
                x = ['Bachelor’s degree', 'Master’s degree', "Some college/university without bachelor's degree", 'Doctoral degree','I prefer not to answer','Professional degree','No formal education past high school'], #temp_df['index'],
                y = temp_df['Q4'],
                marker = dict(color = '#02f7ef',
                              line=dict(color='#aa02f7',width=1.5)),
                text=temp_df['Q4'], textposition='outside')
layout = go.Layout(template= "plotly_dark",title = 'EDUCATION LEVEL OF INDIAN STUDENT KAGGLERS' , xaxis = dict(title = 'Education Level'), yaxis = dict(title = 'Count'), height=650)
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="f0a12c8a-662f-4057-984a-76023a9347e7" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0a12c8a-662f-4057-984a-76023a9347e7")) {                    Plotly.newPlot(                        "f0a12c8a-662f-4057-984a-76023a9347e7",                        [{"marker": {"color": "#02f7ef", "line": {"color": "#aa02f7", "width": 1.5}}, "text": [1885.0, 598.0, 225.0, 56.0, 42.0, 29.0, 10.0], "textposition": "outside", "type": "bar", "x": ["Bachelor\u2019s degree", "Master\u2019s degree", "Some college/university without bachelor's degree", "Doctoral degree", "I prefer not to answer", "Professional degree", "No formal education past high school"], "y": [1885, 598, 225, 56, 42, 29, 10]}],                        {"height":
# ...

# %%
def pie_plot(cnt_srs, title):
    labels=cnt_srs.index
    values=cnt_srs.values
    trace = go.Pie(labels=labels, 
                   values=values, 
                   title=title, 
                   hoverinfo='percent+value+label', 
                   textinfo='percent',
                   textposition='inside',
                   hole=0.6,
                   showlegend=True,
                   marker=dict(colors=plt.cm.viridis_r(np.linspace(0, 1, 28)),
                               line=dict(color='#000000',
                                         width=2),
                              )
                  )
    
    return trace

# %%
trace = go.Pie(labels=['Bachelor’s degree', 'Master’s degree', 'Some college/university without bachelor’s degree',
                       'Doctoral degree', 'I prefer not to answer', "Professional degree", 'No formal education past high school'], 
               values=df['Q4'].value_counts().values, 
               title="Education Level Distribution", 
               hoverinfo='percent+value+label', 
               textinfo='percent',
               textposition='inside',
               hole=0.6,
               showlegend=True,
               marker=dict(colors=plt.cm.viridis_r(np.linspace(0, 1, 28)),
                           line=dict(color='#000000',
                                     width=2),
                          )
                  )
fig=go.Figure(data=[trace])
fig.show()
# Out:
# <div>                            <div id="7d2f96c6-3a2d-41a8-9a4f-c11befaa40b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d2f96c6-3a2d-41a8-9a4f-c11befaa40b0")) {                    Plotly.newPlot(                        "7d2f96c6-3a2d-41a8-9a4f-c11befaa40b0",                        [{"hole": 0.6, "hoverinfo": "percent+value+label", "labels": ["Bachelor\u2019s degree", "Master\u2019s degree", "Some college/university without bachelor\u2019s degree", "Doctoral degree", "I prefer not to answer", "Professional degree", "No formal education past high school"], "marker": {"colors": [[0.993248, 0.906157, 0.143936, 1.0], [0.906311, 0.894855, 0.098125, 1.0], [0.814576, 0.883393, 0.110347, 1.0], [0.709898, 0.868751, 0.169257, 1.0], [0.616293, 0.852709
# ...

# %% [markdown]
#  #### As we observed from above that more than 66% students are pursuing their Bachelor's Degree

# %% [markdown]
# # Gender Diversity

# %%
temp_df = df["Q2"].value_counts().reset_index()

trace1 = go.Bar(
                x = temp_df['index'],
                y = temp_df['Q2'],
                marker = dict(color = '#02f795',
                              line=dict(color='#6002f7',width=1.5)),
                text=temp_df['Q2'], textposition='outside')
layout = go.Layout(template= "plotly_dark",title = 'GENDER DISTRIBUTION AMONG INDIAN STUDENTS ON KAGGLE' , xaxis = dict(title = 'Gender'), yaxis = dict(title = 'Count'), height=650)
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="a2d2a2e1-25d1-40c3-8a7f-aa697c12f02e" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2d2a2e1-25d1-40c3-8a7f-aa697c12f02e")) {                    Plotly.newPlot(                        "a2d2a2e1-25d1-40c3-8a7f-aa697c12f02e",                        [{"marker": {"color": "#02f795", "line": {"color": "#6002f7", "width": 1.5}}, "text": [2070.0, 738.0, 33.0, 2.0, 2.0], "textposition": "outside", "type": "bar", "x": ["Man", "Woman", "Prefer not to say", "Nonbinary", "Prefer to self-describe"], "y": [2070, 738, 33, 2, 2]}],                        {"height": 650, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.
# ...

# %%
figure=go.Figure(data=[pie_plot(df['Q2'].value_counts(), 'Gender Distribution')])
iplot(figure)
# Out:
# <div>                            <div id="8f9c5623-0fe0-4e42-a112-ebb30d9a6417" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f9c5623-0fe0-4e42-a112-ebb30d9a6417")) {                    Plotly.newPlot(                        "8f9c5623-0fe0-4e42-a112-ebb30d9a6417",                        [{"hole": 0.6, "hoverinfo": "percent+value+label", "labels": ["Man", "Woman", "Prefer not to say", "Nonbinary", "Prefer to self-describe"], "marker": {"colors": [[0.993248, 0.906157, 0.143936, 1.0], [0.906311, 0.894855, 0.098125, 1.0], [0.814576, 0.883393, 0.110347, 1.0], [0.709898, 0.868751, 0.169257, 1.0], [0.616293, 0.852709, 0.230052, 1.0], [0.515992, 0.831158, 0.294279, 1.0], [0.430983, 0.808473, 0.346476, 1.0], [0.344074, 0.780029, 0.397381, 1.0], [0.274149,
# ...

# %% [markdown]
# #### OMG !!!! It seems kaggle in terms of quantity wise , largely dominated by Indian male students

# %% [markdown]
# # Age Distribution

# %%
temp_df = df["Q1"].value_counts().reset_index()

trace1 = go.Bar(
                x = temp_df['index'],
                y = temp_df['Q1'],
                marker = dict(color = '#f70227',
                              line=dict(color='#ebf702',width=1.5)),
                text=temp_df['Q1'], textposition='outside')
layout = go.Layout(template= "plotly_dark",title = 'AGE DISTRIBUTION AMONG INDIAN STUDENTS ON KAGGLE' , xaxis = dict(title = 'Age Group'), yaxis = dict(title = 'Count'), height=650)
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="55705423-4346-417b-85ed-91b5824c410a" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55705423-4346-417b-85ed-91b5824c410a")) {                    Plotly.newPlot(                        "55705423-4346-417b-85ed-91b5824c410a",                        [{"marker": {"color": "#f70227", "line": {"color": "#ebf702", "width": 1.5}}, "text": [2065.0, 578.0, 140.0, 31.0, 17.0, 6.0, 4.0, 2.0, 2.0], "textposition": "outside", "type": "bar", "x": ["18-21", "22-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "60-69"], "y": [2065, 578, 140, 31, 17, 6, 4, 2, 2]}],                        {"height": 650, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"lin
# ...

# %%
trace = go.Pie(labels=df['Q1'].value_counts().index, 
               values=df['Q1'].value_counts().values, 
               hoverinfo='percent+value+label', 
               textinfo='percent',
               textposition='inside',
               showlegend=True,
               marker=dict(colors=plt.cm.viridis_r(np.linspace(0, 1, 28)),
                           line=dict(color='#000000',
                                     width=2),
                          )
                  )
layout = go.Layout(title="Age Group Distribution")
fig=go.Figure(data=[trace], layout=layout)
fig.show()
# Out:
# <div>                            <div id="b9a4bc82-86bf-453d-b67e-80122f365fd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9a4bc82-86bf-453d-b67e-80122f365fd4")) {                    Plotly.newPlot(                        "b9a4bc82-86bf-453d-b67e-80122f365fd4",                        [{"hoverinfo": "percent+value+label", "labels": ["18-21", "22-24", "25-29", "30-34", "35-39", "40-44", "45-49", "50-54", "60-69"], "marker": {"colors": [[0.993248, 0.906157, 0.143936, 1.0], [0.906311, 0.894855, 0.098125, 1.0], [0.814576, 0.883393, 0.110347, 1.0], [0.709898, 0.868751, 0.169257, 1.0], [0.616293, 0.852709, 0.230052, 1.0], [0.515992, 0.831158, 0.294279, 1.0], [0.430983, 0.808473, 0.346476, 1.0], [0.344074, 0.780029, 0.397381, 1.0], [0.274149, 0.751988
# ...

# %% [markdown]
# #### As we can observe from above that almost 73% of the students are in the age group of 18-21 years

# %% [markdown]
# # Coding Experience

# %%
temp_df = df["Q6"].value_counts().reset_index()

trace1 = go.Bar(
                x = temp_df['index'],
                y = temp_df['Q6'],
                marker = dict(color = '#f75c02',
                              line=dict(color='#f7e702',width=1.5)),
                text=temp_df['Q6'], textposition='outside')
layout = go.Layout(template= "plotly_dark",title = 'CODING EXPERIENCE' , xaxis = dict(title = 'Years'), yaxis = dict(title = 'Count'), height=650)
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="9e1b4ebd-b031-4f5e-9506-88a89cdd52a9" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e1b4ebd-b031-4f5e-9506-88a89cdd52a9")) {                    Plotly.newPlot(                        "9e1b4ebd-b031-4f5e-9506-88a89cdd52a9",                        [{"marker": {"color": "#f75c02", "line": {"color": "#f7e702", "width": 1.5}}, "text": [1306.0, 1041.0, 383.0, 90.0, 12.0, 10.0, 3.0], "textposition": "outside", "type": "bar", "x": ["1-3 years", "< 1 years", "3-5 years", "5-10 years", "I have never written code", "10-20 years", "20+ years"], "y": [1306, 1041, 383, 90, 12, 10, 3]}],                        {"height": 650, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}
# ...

# %% [markdown]
# #### The above result not surprise me , as expected  most of the students have very less coding experience

# %% [markdown]
# # Programming Languages Used

# %%
Q7_options = []
Q7_values = []

# %%
for col in df.columns:
    if 'Q7' in col:
        Q7_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q7_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q7_values, Q7_options = (list(t) for t in zip(*sorted(zip(Q7_values, Q7_options))))
colors = ['#02f7c2']*len(Q7_values)
colors[-1] = '#0295f7'

trace1 = go.Bar(
                x = Q7_values,
                y = Q7_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                text=Q7_values, textposition='outside', orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'PROGRAMMING LANGUAGES USED BY INDIAN STUDENTS' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'Language'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="2188329d-140d-4147-97d6-ec4f9eb11558" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2188329d-140d-4147-97d6-ec4f9eb11558")) {                    Plotly.newPlot(                        "2188329d-140d-4147-97d6-ec4f9eb11558",                        [{"marker": {"color": ["#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#02f7c2", "#0295f7"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "text": ["10", "16", "24", "77", "102", "365", "393", "498", "814", "998", "1271", "1314", "2625"], "textposition": "outside", "type": "bar", "x": [10, 16, 24, 77, 102, 365, 393, 498, 814, 998, 1271, 1314, 2625], "y": ["Swift", "None
# ...

# %% [markdown]
# #### From above we observe that Python take a huge leap on C++ to become the most used programming language by Indian students

# %% [markdown]
# # Programming Languages Recommended to learn first

# %%
temp_df = df["Q8"].value_counts(normalize=True).reset_index()

trace1 = go.Bar(
                x = temp_df['index'],
                y = temp_df['Q8'],
                marker = dict(color = '#02baf7',
                              line=dict(color='#7502f7',width=1.5)),
                text=temp_df['Q8'], textposition='outside', texttemplate='%{text:.3f}')
layout = go.Layout(template= "plotly_dark",title = 'PROGRAMMING LANGUAGE RECOMMENDED TO LEARN FIRST' , xaxis = dict(title = 'Programming Language'), yaxis = dict(title = 'Percentage'), height=650)
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="d231e59b-9c7f-4baf-8a65-4e0f999c3ee9" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d231e59b-9c7f-4baf-8a65-4e0f999c3ee9")) {                    Plotly.newPlot(                        "d231e59b-9c7f-4baf-8a65-4e0f999c3ee9",                        [{"marker": {"color": "#02baf7", "line": {"color": "#7502f7", "width": 1.5}}, "text": [0.833745146487822, 0.039534062830921285, 0.03565125308859866, 0.029650547123190964, 0.025061771973173313, 0.015178256265442993, 0.008824567596187787, 0.003882809742322626, 0.0028238616307800918, 0.0024708789269325803, 0.0017649135192375574, 0.0014119308153900459], "textposition": "outside", "texttemplate": "%{text:.3f}", "type": "bar", "x": ["Python", "R", "C", "C++", "SQL", "Ja
# ...

# %% [markdown]
# #### From above we can observe that Python ruling with 84% as most recommended first language among the students who Aspiring Data Scientist.

# %% [markdown]
# # IDE's Preferred

# %%
Q9_options = []
Q9_values = []

# %%
for col in df.columns:
    if 'Q9' in col:
        Q9_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q9_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q9_values, Q9_options = (list(t) for t in zip(*sorted(zip(Q9_values, Q9_options))))
fig = go.Figure(data=[go.Table(header=dict(values=['IDE', 'Count'], fill_color='#02f7f7', line_color='darkslategray'),
                 cells=dict(values=[Q9_options, Q9_values], fill_color='lavender', line_color='darkslategray'))
                     ])
fig.show()
# Out:
# <div>                            <div id="e1af03fd-d4a8-4369-b7e2-4ed4ba848801" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1af03fd-d4a8-4369-b7e2-4ed4ba848801")) {                    Plotly.newPlot(                        "e1af03fd-d4a8-4369-b7e2-4ed4ba848801",                        [{"cells": {"fill": {"color": "lavender"}, "line": {"color": "darkslategray"}, "values": [["None", "  Vim / Emacs  ", "Other", "  Notepad++  ", " MATLAB ", " RStudio ", "  Sublime Text  ", "  Spyder  ", " Visual Studio ", "Jupyter (JupyterLab, Jupyter Notebooks, etc) ", " PyCharm ", " Visual Studio Code (VSCode) ", " Jupyter Notebook"], [37, 74, 177, 330, 332, 373, 390, 439, 473, 562, 896, 1445, 1975]]}, "header": {"fill": {"color": "#02f7f7"}, "line": {"color": "
# ...

# %%
colors = ['#0260f7']*len(Q9_values)
colors[-1] = colors[-2] = '#9502f7'

trace1 = go.Bar(
                x = Q9_values,
                y = Q9_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'IDE PREFERRED BY INDIAN STUDENTS' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'IDE'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="82c1fd88-2e75-4fb9-97be-1f44db84cded" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82c1fd88-2e75-4fb9-97be-1f44db84cded")) {                    Plotly.newPlot(                        "82c1fd88-2e75-4fb9-97be-1f44db84cded",                        [{"marker": {"color": ["#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#0260f7", "#9502f7", "#9502f7"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "type": "bar", "x": [37, 74, 177, 330, 332, 373, 390, 439, 473, 562, 896, 1445, 1975], "y": ["None", "  Vim / Emacs  ", "Other", "  Notepad++  ", " MATLAB ", " RStudio ", "  Sublime Text  ", "  Spyder  ", " Visual Studio ", "Jupyter 
# ...

# %% [markdown]
# #### From above we see that JupyterLabs/Jupyter Notebooks is the first choice for Indian Students followed by VSCode, although stil have quite good gap between JupyterLabs/Jupyter Notebooks and VSCode

# %% [markdown]
# # Notebook Products Preffered

# %%
Q10_options = []
Q10_values = []

# %%
for col in df.columns:
    if 'Q10' in col:
        Q10_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q10_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q10_values, Q10_options = (list(t) for t in zip(*sorted(zip(Q10_values, Q10_options))))
fig = go.Figure(data=[go.Table(header=dict(values=['Notebook Products', 'Count'], fill_color='#cff702', line_color='darkslategray'),
                 cells=dict(values=[Q10_options, Q10_values], fill_color='lavender', line_color='darkslategray'))
                     ])
fig.show()
# Out:
# <div>                            <div id="edb12360-ce80-486d-b9ee-1e42755b2c71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edb12360-ce80-486d-b9ee-1e42755b2c71")) {                    Plotly.newPlot(                        "edb12360-ce80-486d-b9ee-1e42755b2c71",                        [{"cells": {"fill": {"color": "lavender"}, "line": {"color": "darkslategray"}, "values": [[" Zeppelin / Zepl Notebooks ", " Databricks Collaborative Notebooks ", " Observable Notebooks ", " Deepnote Notebooks ", " Code Ocean ", " Paperspace / Gradient ", " Amazon EMR Notebooks ", " Amazon Sagemaker Studio Notebooks ", "Other", "Azure Notebooks", " IBM Watson Studio ", "Google Cloud Datalab", "Google Cloud Notebooks (AI Platform / Vertex AI) ", " Binder / JupyterHu
# ...

# %%
colors = ['#02f789']*len(Q10_values)
colors[-1] = colors[-2] = '#02a6f7'

trace1 = go.Bar(
                x = Q10_values,
                y = Q10_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'NOTEBOOK PRODUCTS PREFERRED BY INDIAN KAGGLERS' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'NOTEBOOK PRODUCT'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="a6666a93-e14d-48cd-a0c2-f0cef4f9745e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6666a93-e14d-48cd-a0c2-f0cef4f9745e")) {                    Plotly.newPlot(                        "a6666a93-e14d-48cd-a0c2-f0cef4f9745e",                        [{"marker": {"color": ["#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02f789", "#02a6f7", "#02a6f7"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "type": "bar", "x": [12, 14, 14, 16, 25, 28, 30, 48, 76, 110, 150, 214, 264, 281, 635, 1265, 1373], "y": [" Zeppelin / Zepl Notebooks ", " Databricks Collaborative Notebooks ", " Observable
# ...

# %% [markdown]
# #### From above we oberve that Colab and Kaggle Notebooks are the most preffered Notebook Products

# %% [markdown]
# # Computing Platform Frequently Used

# %%
temp_df = df["Q11"].value_counts().reset_index()

trace1 = go.Bar(
                x = ['Personal Computer', 'Cloud Computing Platform', 'None', 'Deep learning workstation', 'Other'],
                y = temp_df['Q11'],
                marker = dict(color = '#8b46fa',
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                text=temp_df['Q11'], textposition='outside')
layout = go.Layout(template= "plotly_dark",title = 'COMPUTING PLATFORM FREQUENTLY USED' , xaxis = dict(title = 'Computing Platform'), yaxis = dict(title = 'Count'), height=650)
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="c4d81370-d5a0-4020-ae71-a2dbdcc509e0" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4d81370-d5a0-4020-ae71-a2dbdcc509e0")) {                    Plotly.newPlot(                        "c4d81370-d5a0-4020-ae71-a2dbdcc509e0",                        [{"marker": {"color": "#8b46fa", "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "text": [2314.0, 253.0, 153.0, 35.0, 26.0, 5.0], "textposition": "outside", "type": "bar", "x": ["Personal Computer", "Cloud Computing Platform", "None", "Deep learning workstation", "Other"], "y": [2314, 253, 153, 35, 26, 5]}],                        {"height": 650, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"c
# ...

# %% [markdown]
# #### Above result show us that maximum students prefer using their own Personal Computers as the preffered computing platform

# %% [markdown]
# # Hardware Used on a Regular Basis

# %%
Q12_options = []
Q12_values = []

# %%
for col in df.columns:
    if 'Q12' in col:
        Q12_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q12_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q12_values, Q12_options = (list(t) for t in zip(*sorted(zip(Q12_values, Q12_options))))

trace1 = go.Bar(
                x = Q12_values,
                y = Q12_options,
                marker = dict(color = '#bdfa05',
                              line=dict(color='rgb(0,0,0)')),
                text=Q12_values, textposition='outside', orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'HARDWARE FREQUENTLY USED' , xaxis = dict(title = 'Count'), yaxis = dict(title = 'Hardware'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="1ef79f28-b2ad-4372-b2d6-5341b6e5a916" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ef79f28-b2ad-4372-b2d6-5341b6e5a916")) {                    Plotly.newPlot(                        "1ef79f28-b2ad-4372-b2d6-5341b6e5a916",                        [{"marker": {"color": "#bdfa05", "line": {"color": "rgb(0,0,0)"}}, "orientation": "h", "text": ["40", "41", "132", "432", "830", "1494"], "textposition": "outside", "type": "bar", "x": [40, 41, 132, 432, 830, 1494], "y": [" AWS Inferentia Chips ", " AWS Trainium Chips ", "Other", " Google Cloud TPUs ", " NVIDIA GPUs ", "None"]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"lin
# ...

# %% [markdown]
# #### Above result tell us that maximum Students prefer CPUs and GPUs on a regular basis but also we can see that between CPUs and GPUs have huge gap

# %% [markdown]
# # Favourite Machine Learning Framework

# %%
Q16_options = []
Q16_values = []

# %%
for col in df.columns:
    if 'Q16' in col:
        Q16_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q16_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q16_values, Q16_options = (list(t) for t in zip(*sorted(zip(Q16_values, Q16_options))))
fig = go.Figure(data=[go.Table(header=dict(values=['Machine Learning Framework', 'Count'], fill_color='lightblue', line_color='darkslategray'),
                 cells=dict(values=[Q16_options, Q16_values], fill_color='lavender', line_color='darkslategray'))
                     ])
fig.show()
# Out:
# <div>                            <div id="aeb70be2-5fb5-4e26-abc4-8ceb41706103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeb70be2-5fb5-4e26-abc4-8ceb41706103")) {                    Plotly.newPlot(                        "aeb70be2-5fb5-4e26-abc4-8ceb41706103",                        [{"cells": {"fill": {"color": "lavender"}, "line": {"color": "darkslategray"}, "values": [[" JAX ", " MXNet ", " H2O 3 ", " Prophet ", " Tidymodels ", "Other", " Caret ", " Fast.ai ", " Huggingface ", " PyTorch Lightning ", " CatBoost ", " LightGBM ", "None", " PyTorch ", " Xgboost ", " Keras ", "  TensorFlow ", "  Scikit-learn "], [11, 14, 21, 22, 25, 31, 38, 67, 86, 92, 113, 167, 218, 499, 520, 827, 994, 1428]]}, "header": {"fill": {"color": "lightblue"}, "line"
# ...

# %%
colors = ['#05f6fa']*len(Q16_values)
colors[-1] = colors[-2] = '#0542fa'

trace1 = go.Bar(
                x = Q16_values,
                y = Q16_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'FAVOURITE MACHINE LEARNING FRAMEWORK' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'ML Framework'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="9d535d19-01f1-4e63-82df-7d5892fe0043" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d535d19-01f1-4e63-82df-7d5892fe0043")) {                    Plotly.newPlot(                        "9d535d19-01f1-4e63-82df-7d5892fe0043",                        [{"marker": {"color": ["#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#05f6fa", "#0542fa", "#0542fa"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "type": "bar", "x": [11, 14, 21, 22, 25, 31, 38, 67, 86, 92, 113, 167, 218, 499, 520, 827, 994, 1428], "y": [" JAX ", " MXNet ", " H2O 3 ", " Prophet ", " Tidymodels ", "Other", 
# ...

# %% [markdown]
# #### Scikit-learn, Tensorflow and Keras are the most preffered ML Frameworks but it seems that Scikit-learn mostly preffered ML Frameworks in dominate way

# %% [markdown]
# # Favourite Machine Learning Algorithm

# %%
Q17_options = []
Q17_values = []

# %%
for col in df.columns:
    if 'Q17' in col:
        Q17_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q17_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q17_values, Q17_options = (list(t) for t in zip(*sorted(zip(Q17_values, Q17_options))))
fig = go.Figure(data=[go.Table(header=dict(values=['Machine Learning Algorithm', 'Count'], fill_color='lightseagreen', line_color='darkslategray'),
                 cells=dict(values=[Q17_options, Q17_values], fill_color='lavender', line_color='darkslategray'))
                     ])
fig.show()
# Out:
# <div>                            <div id="971acb3a-6f81-439a-ab2f-4d30564e8f72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("971acb3a-6f81-439a-ab2f-4d30564e8f72")) {                    Plotly.newPlot(                        "971acb3a-6f81-439a-ab2f-4d30564e8f72",                        [{"cells": {"fill": {"color": "lavender"}, "line": {"color": "darkslategray"}, "values": [["Other", "Evolutionary Approaches", "Generative Adversarial Networks", "Transformer Networks (BERT, gpt-3, etc)", "None", "Recurrent Neural Networks", "Dense Neural Networks (MLPs, etc)", "Bayesian Approaches", "Gradient Boosting Machines (xgboost, lightgbm, etc)", "Convolutional Neural Networks", "Decision Trees or Random Forests", "Linear or Logistic Regression"], [24, 58,
# ...

# %%
colors = ['#fa9805']*len(Q17_values)
colors[-1] = colors[-2] = colors[-3] = '#fa2205'

trace1 = go.Bar(
                x = Q17_values,
                y = Q17_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'FAVOURITE MACHINE LEARNING ALGORITHM' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'ML ALgorithm'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="922fc718-9671-4794-9811-fe4768c5a38e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("922fc718-9671-4794-9811-fe4768c5a38e")) {                    Plotly.newPlot(                        "922fc718-9671-4794-9811-fe4768c5a38e",                        [{"marker": {"color": ["#fa9805", "#fa9805", "#fa9805", "#fa9805", "#fa9805", "#fa9805", "#fa9805", "#fa9805", "#fa9805", "#fa2205", "#fa2205", "#fa2205"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "type": "bar", "x": [24, 58, 112, 158, 166, 394, 410, 418, 602, 737, 1190, 1437], "y": ["Other", "Evolutionary Approaches", "Generative Adversarial Networks", "Transformer Networks (BERT, gpt-3, etc)", "None", "Recurrent Neural Networks", "Dens
# ...

# %% [markdown]
# #### From above we observe that Linear/Logistic Regression and Tree-based models are the most preffered ML Algorithms

# %% [markdown]
# # Computer Vision Applications Used Frequently

# %%
Q18_options = []
Q18_values = []

# %%
for col in df.columns:
    if 'Q18' in col:
        Q18_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q18_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
trace = go.Pie(labels=['General purpose image/video tools', 'Image Segmentation methods', 'Object Detection methods',
                       'Image Classification', 'Generative Networks', 'None', 'Other'], 
               values=Q18_values, 
               title="Computer Vision Applications", 
               hoverinfo='percent+value+label', 
               textinfo='percent',
               textposition='inside',
               hole=0.6,
               showlegend=True,
               marker=dict(colors=plt.cm.viridis_r(np.linspace(0, 1, 28)),
                           line=dict(color='#000000',
                                     width=2),
                          )
                  )
fig = go.Figure(data=[trace])
fig.show()
# Out:
# <div>                            <div id="ba1df64a-420c-4f34-adf1-cc1012d282fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba1df64a-420c-4f34-adf1-cc1012d282fc")) {                    Plotly.newPlot(                        "ba1df64a-420c-4f34-adf1-cc1012d282fc",                        [{"hole": 0.6, "hoverinfo": "percent+value+label", "labels": ["General purpose image/video tools", "Image Segmentation methods", "Object Detection methods", "Image Classification", "Generative Networks", "None", "Other"], "marker": {"colors": [[0.993248, 0.906157, 0.143936, 1.0], [0.906311, 0.894855, 0.098125, 1.0], [0.814576, 0.883393, 0.110347, 1.0], [0.709898, 0.868751, 0.169257, 1.0], [0.616293, 0.852709, 0.230052, 1.0], [0.515992, 0.831158, 0.294279, 1.0], [0
# ...

# %% [markdown]
#  #### Above result  tell us that Image Classification, Image Segmentation, General purpose tools and Object Detection are the Most Common applications of Computer Vision

# %% [markdown]
# # Natural Language Processing Methods Used Frequently

# %%
Q19_options = []
Q19_values = []

# %%
for col in df.columns:
    if 'Q19' in col:
        Q19_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q19_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
trace = go.Pie(labels=Q19_options, 
               values=Q19_values, 
               title="NLP Methods", 
               hoverinfo='percent+value+label', 
               textinfo='percent',
               textposition='inside',
               hole=0.6,
               showlegend=True,
               marker=dict(colors=plt.cm.viridis_r(np.linspace(0, 1, 28)),
                           line=dict(color='#000000',
                                     width=2),
                          )
                  )
fig = go.Figure(data=[trace])
fig.show()
# Out:
# <div>                            <div id="91df0991-de67-4630-bbad-d03ed0de738a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91df0991-de67-4630-bbad-d03ed0de738a")) {                    Plotly.newPlot(                        "91df0991-de67-4630-bbad-d03ed0de738a",                        [{"hole": 0.6, "hoverinfo": "percent+value+label", "labels": ["Word embeddings/vectors (GLoVe, fastText, word2vec)", "Encoder-decorder models (seq2seq, vanilla transformers)", "Contextualized embeddings (ELMo, CoVe)", "Transformer language models (GPT-3, BERT, XLnet, etc)", "None", "Other"], "marker": {"colors": [[0.993248, 0.906157, 0.143936, 1.0], [0.906311, 0.894855, 0.098125, 1.0], [0.814576, 0.883393, 0.110347, 1.0], [0.709898, 0.868751, 0.169257, 1.0], [0.61
# ...

# %% [markdown]
# #### From above we see that Word Embeddings, Transformer models Encoder-Decoder models and Encoder-Decoder models are the most frequently used NLP methods

# %% [markdown]
# # Favourite Visualization Tools

# %%
Q14_options = []
Q14_values = []

# %%
for col in df.columns:
    if 'Q14' in col:
        Q14_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q14_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q14_values, Q14_options = (list(t) for t in zip(*sorted(zip(Q14_values, Q14_options))))

colors = ['#2e05fa']*len(Q14_values)
colors[-1] = colors[-2] = '#88fa05'

trace1 = go.Bar(
                x = Q14_values,
                y = Q14_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'FAVOURITE VISUALIZATION TOOLS' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'Visualization Tool'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="918cbb0a-dd9b-4abb-81d0-3492c821e657" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("918cbb0a-dd9b-4abb-81d0-3492c821e657")) {                    Plotly.newPlot(                        "918cbb0a-dd9b-4abb-81d0-3492c821e657",                        [{"marker": {"color": ["#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#2e05fa", "#88fa05", "#88fa05"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "type": "bar", "x": [17, 35, 43, 45, 52, 71, 134, 378, 431, 523, 1429, 2004], "y": [" Altair ", " Leaflet / Folium ", " D3 js ", " Shiny ", " Bokeh ", "Other", " Geoplotlib ", " Ggplot / ggplot2 ", "None", " Plotly / Plotly Express ", " Seaborn
# ...

# %% [markdown]
# #### From above we observe that  Matplotlib and seaborn are the most common plotting tools used , but still Matplotlib dominates

# %% [markdown]
# # Platform to Share and Deploy Data Science Applications

# %%
Q36_cols = []
for col in df.columns:
    if 'Q36' in col:
        Q36_cols.append(col)

# %%
df[Q36_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2845 entries, 7 to 25952
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Q36_A_Part_1  0 non-null      object
#  1   Q36_A_Part_2  0 non-null      object
#  2   Q36_A_Part_3  0 non-null      object
#  3   Q36_A_Part_4  0 non-null      object
#  4   Q36_A_Part_5  0 non-null      object
#  5   Q36_A_Part_6  0 non-null      object
#  6   Q36_A_Part_7  0 non-null      object
#  7   Q36_A_OTHER   0 non-null      object
#  8   Q36_B_Part_1  528 non-null    object
#  9   Q36_B_Part_2  513 non-null    object
#  10  Q36_B_Part_3  762 non-null    object
#  11  Q36_B_Part_4  329 non-null    object
#  12  Q36_B_Part_5  485 non-null    object
#  13  Q36_B_Part_6  808 non-null    object
#  14  Q36_B_Part_7  432 non-null    object
#  15  Q36_B_OTHER   44 non-null     object
# dtypes: object(16)
# memory usage: 377.9+ KB

# %% [markdown]
# #### All the values are NaNs

# %% [markdown]
# # Platforms for Data science courses

# %%
Q37_options = []
Q37_values = []

# %%
for col in df.columns:
    if 'Q37' in col:
        Q37_options.extend(df[col].value_counts().reset_index()['index'].tolist())
        Q37_values.extend(df[col].value_counts().reset_index()[col].tolist())

# %%
Q37_values, Q37_options = (list(t) for t in zip(*sorted(zip(Q37_values, Q37_options))))
Q37_options = ['Fast.ai', 'None', 'Cloud-certification programs', 'LinkedIn Learning', 'Udacity', 'edX', 'Other', 'Datacamp', 'University Courses', 'Udemy', 'Kaggle Learn Courses', 'Coursera']

colors = ['#c505fa']*len(Q37_values)
colors[-1] = '#fa05b9'

trace1 = go.Bar(
                x = Q37_values,
                y = Q37_options,
                marker = dict(color = colors,
                              line=dict(color='rgb(0,0,0)',width=1.5)),
                orientation='h')
layout = go.Layout(template= "plotly_dark",title = 'PLATFORMS FOR DATA SCIENCE COURSES' , xaxis = dict(title = 'Count', automargin=True), yaxis = dict(title = 'Data Science Platform'))
fig = go.Figure(data = [trace1], layout = layout)
fig.show()
# Out:
# <div>                            <div id="1aaa42cd-71f2-4ca8-a162-2728e770714e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1aaa42cd-71f2-4ca8-a162-2728e770714e")) {                    Plotly.newPlot(                        "1aaa42cd-71f2-4ca8-a162-2728e770714e",                        [{"marker": {"color": ["#c505fa", "#c505fa", "#c505fa", "#c505fa", "#c505fa", "#c505fa", "#c505fa", "#fa05b9"], "line": {"color": "rgb(0,0,0)", "width": 1.5}}, "orientation": "h", "type": "bar", "x": [34, 175, 230, 230, 246, 474, 515, 794], "y": ["Fast.ai", "None", "Cloud-certification programs", "LinkedIn Learning", "Udacity", "edX", "Other", "Datacamp", "University Courses", "Udemy", "Kaggle Learn Courses", "Coursera"]}],                        {"template": {"da
# ...

# %% [markdown]
#  #### From above we see that Datacamp is the most widely preffered platform for Data Science Courses

# %%
from IPython.display import Image
Image(filename='man.jpg')

# %% [markdown]
# ## Consider Upvoting the kernel If you like My Piece of work :)
